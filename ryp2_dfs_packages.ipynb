# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri
from rpy2.robjects.packages import importr

# %%
features = [i.replace(' ', '_') for i in load_breast_cancer().feature_names.tolist()]

breast_cancer_df = pd.DataFrame(load_breast_cancer().data,columns=features)
target_df = pd.DataFrame(load_breast_cancer().target, columns=['y'])

df = pd.concat([breast_cancer_df,target_df],axis=1)

# %%
data = pandas2ri.converter.py2ri(df)
# Out:
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "mean_radius". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "mean_texture". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "mean_perimeter". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "mean_area". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "mean_smoothness". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "mean_compactness". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "mean_concavity". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "mean_concave_points". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "mean_symmetry". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "mean_fractal_dimension". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "radius_error". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "texture_error". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "perimeter_error". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "area_error". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "smoothness_error". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "compactness_error". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "concavity_error". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "concave_points_error". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "symmetry_error". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "fractal_dimension_error". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "worst_radius". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "worst_texture". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "worst_perimeter". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "worst_area". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "worst_smoothness". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "worst_compactness". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "worst_concavity". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "worst_concave_points". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "worst_symmetry". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "worst_fractal_dimension". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))
# /Users/remycanario/anaconda3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:67: UserWarning: Error while trying to convert the column "y". Fall back to string conversion. The error is: Conversion 'py2ri' not defined for objects of type '<class 'pandas.core.series.Series'>'
#   (name, str(e)))

# %%
base = importr('base')
d = {'package.dependencies': 'package_dot_dependencies',
     'package_dependencies': 'package_uscore_dependencies'}

# %%
conda install -c r r-essentials
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - <unknown>/osx-64::r-elrm==1.2.4=r36h466af19_0
#   - <unknown>/osx-64::r-coda==0.17_1=r3.2.0_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - <unknown>/osx-64::r-elrm==1.2.4=r36h466af19_0
#   - <unknown>/osx-64::r-coda==0.17_1=r3.2.0_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/remycanario/anaconda3
#
#   added / updated specs:
#     - r-essentials
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.0                |           py37_1         2.8 MB
#     r-base64enc-0.1_3          |    r36h46e59ec_4          31 KB  r
#     r-caret-6.0_83             |    r36h46e59ec_0         6.0 MB  r
#     r-class-7.3_15             |    r36h46e59ec_0          93 KB  r
#     r-coda-0.19_2              |    r36h6115d3f_0         354 KB  r
#     r-codetools-0.2_16         |    r36h6115d3f_0         107 KB  r
#     r-colorspace-1.4_1         |    r36h46e59ec_0         2.5 MB  r
#     r-curl-3.3                 |    r36h46e59ec_0         403 KB  r
#     r-data.table-1.12.2        |    r36h46e59ec_0         1.5 MB  r
#     r-dichromat-2.0_0          |    r36h6115d3f_4         163 KB  r
#     r-essentials-1.0           |               0a          677 B  r
#     r-evaluate-0.13            |    r36h6115d3f_0          83 KB  r
#     r-foreach-1.4.4            |    r36h6115d3f_0         412 KB  r
#     r-generics-0.0.2           |    r36h6115d3f_0          82 KB  r
#     r-ggplot2-3.1.1            |    r36h6115d3f_0         3.6 MB  r
#     r-glmnet-2.0_16            |    r36hfffe0aa_0         1.4 MB  r
#     r-gower-0.2.0              |    r36h46e59ec_0         170 KB  r
#     r-gtable-0.3.0             |    r36h6115d3f_0         425 KB  r
#     r-highr-0.8                |    r36h6115d3f_0          60 KB  r
#     r-htmltools-0.3.6          |    r36h466af19_0         180 KB  r
#     r-httpuv-1.5.1             |    r36h466af19_0         625 KB  r
#     r-ipred-0.9_8              |    r36h46e59ec_0         391 KB  r
#     r-iterators-1.0.10         |    r36h6115d3f_0         340 KB  r
#     r-jsonlite-1.6             |    r36h46e59ec_0        1013 KB  r
#     r-kernsmooth-2.23_15       |    r36hfffe0aa_4          96 KB  r
#     r-knitr-1.22               |    r36h6115d3f_0         1.3 MB  r
#     r-labeling-0.3             |    r36h6115d3f_4          71 KB  r
#     r-later-0.8.0              |    r36h466af19_0          93 KB  r
#     r-lattice-0.20_38          |    r36h46e59ec_0         1.1 MB  r
#     r-lava-1.6.5               |    r36h6115d3f_0         2.2 MB  r
#     r-lazyeval-0.2.2           |    r36h46e59ec_0         161 KB  r
#     r-lubridate-1.7.4          |    r36h466af19_0         1.0 MB  r
#     r-markdown-0.9             |    r36h46e59ec_0         138 KB  r
#     r-mass-7.3_51.3            |    r36h46e59ec_0         1.1 MB  r
#     r-matrix-1.2_17            |    r36h46e59ec_0         3.8 MB  r
#     r-mgcv-1.8_28              |    r36h46e59ec_0         2.7 MB  r
#     r-mime-0.6                 |    r36h46e59ec_0          49 KB  r
#     r-modelmetrics-1.2.2       |    r36h466af19_0         153 KB  r
#     r-munsell-0.5.0            |    r36h6115d3f_0         254 KB  r
#     r-nlme-3.1_139             |    r36hfffe0aa_0         2.3 MB  r
#     r-nnet-7.3_12              |    r36h46e59ec_0         121 KB  r
#     r-numderiv-2016.8_1        |    r36h6115d3f_0         132 KB  r
#     r-plyr-1.8.4               |    r36h466af19_0         816 KB  r
#     r-prodlim-2018.04.18       |    r36h466af19_0         407 KB  r
#     r-promises-1.0.1           |    r36h466af19_0         175 KB  r
#     r-quantmod-0.4_14          |    r36h6115d3f_0         1.0 MB  r
#     r-randomforest-4.6_14      |    r36hfffe0aa_0         231 KB  r
#     r-rcolorbrewer-1.1_2       |    r36h6115d3f_0          62 KB  r
#     r-rcpproll-0.3.0           |    r36h466af19_0         114 KB  r
#     r-recipes-0.1.5            |    r36h6115d3f_0         1.4 MB  r
#     r-reshape2-1.4.3           |    r36h466af19_0         121 KB  r
#     r-rmarkdown-1.12           |    r36h6115d3f_0         3.0 MB  r
#     r-rpart-4.1_15             |    r36h46e59ec_0         726 KB  r
#     r-scales-1.0.0             |    r36h466af19_0         577 KB  r
#     r-shiny-1.3.2              |    r36h6115d3f_0         4.3 MB  r
#     r-sourcetools-0.1.7        |    r36h466af19_0          48 KB  r
#     r-squarem-2017.10_1        |    r36h6115d3f_0         302 KB  r
#     r-stringi-1.4.3            |    r36h466af19_0         753 KB  r
#     r-stringr-1.4.0            |    r36h6115d3f_0         221 KB  r
#     r-survival-2.44_1.1        |    r36h46e59ec_0         4.8 MB  r
#     r-tidyr-0.8.3              |    r36h466af19_0         428 KB  r
#     r-timedate-3043.102        |    r36h6115d3f_0         1.6 MB  r
#     r-tinytex-0.12             |    r36h6115d3f_0         106 KB  r
#     r-ttr-0.23_4               |    r36hfffe0aa_0         516 KB  r
#     r-viridislite-0.3.0        |    r36h6115d3f_0          66 KB  r
#     r-withr-2.1.2              |    r36h6115d3f_0         181 KB  r
#     r-xfun-0.6                 |    r36h6115d3f_0         189 KB  r
#     r-xtable-1.8_4             |    r36h6115d3f_0         717 KB  r
#     r-xts-0.11_2               |    r36h46e59ec_0         914 KB  r
#     r-yaml-2.2.0               |    r36h46e59ec_0         107 KB  r
#     r-zoo-1.8_6                |    r36h46e59ec_0         1.1 MB  r
#     ------------------------------------------------------------
#                                            Total:        64.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   r-base64enc        r/osx-64::r-base64enc-0.1_3-r36h46e59ec_4
#   r-caret            r/osx-64::r-caret-6.0_83-r36h46e59ec_0
#   r-class            r/osx-64::r-class-7.3_15-r36h46e59ec_0
#   r-codetools        r/noarch::r-codetools-0.2_16-r36h6115d3f_0
#   r-colorspace       r/osx-64::r-colorspace-1.4_1-r36h46e59ec_0
#   r-curl             r/osx-64::r-curl-3.3-r36h46e59ec_0
#   r-data.table       r/osx-64::r-data.table-1.12.2-r36h46e59ec_0
#   r-dichromat        r/noarch::r-dichromat-2.0_0-r36h6115d3f_4
#   r-essentials       r/osx-64::r-essentials-1.0-0a
#   r-evaluate         r/noarch::r-evaluate-0.13-r36h6115d3f_0
#   r-foreach          r/noarch::r-foreach-1.4.4-r36h6115d3f_0
#   r-generics         r/noarch::r-generics-0.0.2-r36h6115d3f_0
#   r-ggplot2          r/noarch::r-ggplot2-3.1.1-r36h6115d3f_0
#   r-glmnet           r/osx-64::r-glmnet-2.0_16-r36hfffe0aa_0
#   r-gower            r/osx-64::r-gower-0.2.0-r36h46e59ec_0
#   r-gtable           r/noarch::r-gtable-0.3.0-r36h6115d3f_0
#   r-highr            r/noarch::r-highr-0.8-r36h6115d3f_0
#   r-htmltools        r/osx-64::r-htmltools-0.3.6-r36h466af19_0
#   r-httpuv           r/osx-64::r-httpuv-1.5.1-r36h466af19_0
#   r-ipred            r/osx-64::r-ipred-0.9_8-r36h46e59ec_0
#   r-iterators        r/noarch::r-iterators-1.0.10-r36h6115d3f_0
#   r-jsonlite         r/osx-64::r-jsonlite-1.6-r36h46e59ec_0
#   r-kernsmooth       r/osx-64::r-kernsmooth-2.23_15-r36hfffe0aa_4
#   r-knitr            r/noarch::r-knitr-1.22-r36h6115d3f_0
#   r-labeling         r/noarch::r-labeling-0.3-r36h6115d3f_4
#   r-later            r/osx-64::r-later-0.8.0-r36h466af19_0
#   r-lattice          r/osx-64::r-lattice-0.20_38-r36h46e59ec_0
#   r-lava             r/noarch::r-lava-1.6.5-r36h6115d3f_0
#   r-lazyeval         r/osx-64::r-lazyeval-0.2.2-r36h46e59ec_0
#   r-lubridate        r/osx-64::r-lubridate-1.7.4-r36h466af19_0
#   r-markdown         r/osx-64::r-markdown-0.9-r36h46e59ec_0
#   r-mass             r/osx-64::r-mass-7.3_51.3-r36h46e59ec_0
#   r-matrix           r/osx-64::r-matrix-1.2_17-r36h46e59ec_0
#   r-mgcv             r/osx-64::r-mgcv-1.8_28-r36h46e59ec_0
#   r-mime             r/osx-64::r-mime-0.6-r36h46e59ec_0
#   r-modelmetrics     r/osx-64::r-modelmetrics-1.2.2-r36h466af19_0
#   r-munsell          r/noarch::r-munsell-0.5.0-r36h6115d3f_0
#   r-nlme             r/osx-64::r-nlme-3.1_139-r36hfffe0aa_0
#   r-nnet             r/osx-64::r-nnet-7.3_12-r36h46e59ec_0
#   r-numderiv         r/noarch::r-numderiv-2016.8_1-r36h6115d3f_0
#   r-plyr             r/osx-64::r-plyr-1.8.4-r36h466af19_0
#   r-prodlim          r/osx-64::r-prodlim-2018.04.18-r36h466af19_0
#   r-promises         r/osx-64::r-promises-1.0.1-r36h466af19_0
#   r-quantmod         r/noarch::r-quantmod-0.4_14-r36h6115d3f_0
#   r-randomforest     r/osx-64::r-randomforest-4.6_14-r36hfffe0aa_0
#   r-rcolorbrewer     r/noarch::r-rcolorbrewer-1.1_2-r36h6115d3f_0
#   r-rcpproll         r/osx-64::r-rcpproll-0.3.0-r36h466af19_0
#   r-recipes          r/noarch::r-recipes-0.1.5-r36h6115d3f_0
#   r-reshape2         r/osx-64::r-reshape2-1.4.3-r36h466af19_0
#   r-rmarkdown        r/noarch::r-rmarkdown-1.12-r36h6115d3f_0
#   r-rpart            r/osx-64::r-rpart-4.1_15-r36h46e59ec_0
#   r-scales           r/osx-64::r-scales-1.0.0-r36h466af19_0
#   r-shiny            r/noarch::r-shiny-1.3.2-r36h6115d3f_0
#   r-sourcetools      r/osx-64::r-sourcetools-0.1.7-r36h466af19_0
#   r-squarem          r/noarch::r-squarem-2017.10_1-r36h6115d3f_0
#   r-stringi          r/osx-64::r-stringi-1.4.3-r36h466af19_0
#   r-stringr          r/noarch::r-stringr-1.4.0-r36h6115d3f_0
#   r-survival         r/osx-64::r-survival-2.44_1.1-r36h46e59ec_0
#   r-tidyr            r/osx-64::r-tidyr-0.8.3-r36h466af19_0
#   r-timedate         r/noarch::r-timedate-3043.102-r36h6115d3f_0
#   r-tinytex          r/noarch::r-tinytex-0.12-r36h6115d3f_0
#   r-ttr              r/osx-64::r-ttr-0.23_4-r36hfffe0aa_0
#   r-viridislite      r/noarch::r-viridislite-0.3.0-r36h6115d3f_0
#   r-withr            r/noarch::r-withr-2.1.2-r36h6115d3f_0
#   r-xfun             r/noarch::r-xfun-0.6-r36h6115d3f_0
#   r-xtable           r/noarch::r-xtable-1.8_4-r36h6115d3f_0
#   r-xts              r/osx-64::r-xts-0.11_2-r36h46e59ec_0
#   r-yaml             r/osx-64::r-yaml-2.2.0-r36h46e59ec_0
#   r-zoo              r/osx-64::r-zoo-1.8_6-r36h46e59ec_0
#
# The following packages will be UPDATED:
#
#   conda                                       4.7.12-py37_0 --> 4.8.0-py37_1
#   r-coda             <unknown>/osx-64::r-coda-0.17_1-r3.2.~ --> r/noarch::r-coda-0.19_2-r36h6115d3f_0
#
#
#
# Downloading and Extracting Packages
# r-lazyeval-0.2.2     | 161 KB    | ##################################### | 100%
# r-labeling-0.3       | 71 KB     | ##################################### | 100%
# r-jsonlite-1.6       | 1013 KB   | ##################################### | 100%
# r-zoo-1.8_6          | 1.1 MB    | ##################################### | 100%
# r-tinytex-0.12       | 106 KB    | ##################################### | 100%
# r-rcpproll-0.3.0     | 114 KB    | ##################################### | 100%
# r-later-0.8.0        | 93 KB     | ##################################### | 100%
# r-base64enc-0.1_3    | 31 KB     | ##################################### | 100%
# r-plyr-1.8.4         | 816 KB    | ##################################### | 100%
# r-numderiv-2016.8_1  | 132 KB    | ##################################### | 100%
# conda-4.8.0          | 2.8 MB    | ##################################### | 100%
# r-data.table-1.12.2  | 1.5 MB    | ##################################### | 100%
# r-shiny-1.3.2        | 4.3 MB    | ##################################### | 100%
# r-recipes-0.1.5      | 1.4 MB    | ##################################### | 100%
# r-xtable-1.8_4       | 717 KB    | ##################################### | 100%
# r-matrix-1.2_17      | 3.8 MB    | ##################################### | 100%
# r-ttr-0.23_4         | 516 KB    | ##################################### | 100%
# r-gtable-0.3.0       | 425 KB    | ##################################### | 100%
# r-rpart-4.1_15       | 726 KB    | ##################################### | 100%
# r-kernsmooth-2.23_15 | 96 KB     | ##################################### | 100%
# r-htmltools-0.3.6    | 180 KB    | ##################################### | 100%
# r-mime-0.6           | 49 KB     | ##################################### | 100%
# r-modelmetrics-1.2.2 | 153 KB    | ##################################### | 100%
# r-promises-1.0.1     | 175 KB    | ##################################### | 100%
# r-foreach-1.4.4      | 412 KB    | ##################################### | 100%
# r-nnet-7.3_12        | 121 KB    | ##################################### | 100%
# r-httpuv-1.5.1       | 625 KB    | ##################################### | 100%
# r-tidyr-0.8.3        | 428 KB    | ##################################### | 100%
# r-essentials-1.0     | 677 B     | ##################################### | 100%
# r-xts-0.11_2         | 914 KB    | ##################################### | 100%
# r-scales-1.0.0       | 577 KB    | ##################################### | 100%
# r-rmarkdown-1.12     | 3.0 MB    | ##################################### | 100%
# r-codetools-0.2_16   | 107 KB    | ##################################### | 100%
# r-yaml-2.2.0         | 107 KB    | ##################################### | 100%
# r-ggplot2-3.1.1      | 3.6 MB    | ##################################### | 100%
# r-munsell-0.5.0      | 254 KB    | ##################################### | 100%
# r-generics-0.0.2     | 82 KB     | ##################################### | 100%
# r-ipred-0.9_8        | 391 KB    | ##################################### | 100%
# r-mgcv-1.8_28        | 2.7 MB    | ##################################### | 100%
# r-colorspace-1.4_1   | 2.5 MB    | ##################################### | 100%
# r-glmnet-2.0_16      | 1.4 MB    | ##################################### | 100%
# r-timedate-3043.102  | 1.6 MB    | ##################################### | 100%
# r-lattice-0.20_38    | 1.1 MB    | ##################################### | 100%
# r-highr-0.8          | 60 KB     | ##################################### | 100%
# r-curl-3.3           | 403 KB    | ##################################### | 100%
# r-dichromat-2.0_0    | 163 KB    | ##################################### | 100%
# r-rcolorbrewer-1.1_2 | 62 KB     | ##################################### | 100%
# r-squarem-2017.10_1  | 302 KB    | ##################################### | 100%
# r-markdown-0.9       | 138 KB    | ##################################### | 100%
# r-nlme-3.1_139       | 2.3 MB    | ##################################### | 100%
# r-survival-2.44_1.1  | 4.8 MB    | ##################################### | 100%
# r-sourcetools-0.1.7  | 48 KB     | ##################################### | 100%
# r-randomforest-4.6_1 | 231 KB    | ##################################### | 100%
# r-stringi-1.4.3      | 753 KB    | ##################################### | 100%
# r-evaluate-0.13      | 83 KB     | ##################################### | 100%
# r-gower-0.2.0        | 170 KB    | ##################################### | 100%
# r-class-7.3_15       | 93 KB     | ##################################### | 100%
# r-iterators-1.0.10   | 340 KB    | ##################################### | 100%
# r-caret-6.0_83       | 6.0 MB    | ##################################### | 100%
# r-stringr-1.4.0      | 221 KB    | ##################################### | 100%
# r-xfun-0.6           | 189 KB    | ##################################### | 100%
# r-prodlim-2018.04.18 | 407 KB    | ##################################### | 100%
# r-coda-0.19_2        | 354 KB    | ##################################### | 100%
# r-lubridate-1.7.4    | 1.0 MB    | ##################################### | 100%
# r-lava-1.6.5         | 2.2 MB    | ##################################### | 100%
# r-mass-7.3_51.3      | 1.1 MB    | ##################################### | 100%
# r-knitr-1.22         | 1.3 MB    | ##################################### | 100%
# r-withr-2.1.2        | 181 KB    | ##################################### | 100%
# r-viridislite-0.3.0  | 66 KB     | ##################################### | 100%
# r-reshape2-1.4.3     | 121 KB    | ##################################### | 100%
# r-quantmod-0.4_14    | 1.0 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
